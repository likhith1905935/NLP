# %% [markdown]
# <a href="https://colab.research.google.com/github/likhith1905935/NLP/blob/main/Copy_of_EXP6NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text = "Natural Language Processing is a very important area in Artificial Intelligence"

# %%
nltk.download('punkt_tab')
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens: ['Natural', 'Language', 'Processing', 'is', 'a', 'very', 'important', 'area', 'in', 'Artificial', 'Intelligence']

# %%
stop_words = set(stopwords.words('english'))
print("Stop Words:", stop_words)
# Out:
# Stop Words: {'they', "shouldn't", 'won', 'her', 've', 'below', "we'll", "she's", "it'd", 'himself', 'did', 'off', 'who', "doesn't", 'its', "you'll", 'd', 's', "hadn't", "you'd", 'why', 'their', 'y', "it's", 'o', 'about', 'mustn', 'by', 'further', 'itself', 'being', 'under', 'it', 'when', 'then', 'those', "you've", 'on', 'out', 'a', 'his', 'll', 'isn', 'we', 'were', "they've", 'have', "he's", "they're", 'just', 'weren', 'doing', 'not', 'how', "i'll", 'are', "they'd", 'shan', 'than', "you're", 'now', "shan't", 'him', 'he', "wouldn't", "isn't", 'been', 'does', 'which', 'shouldn', 'i', 'what', 'during', "should've", 'ain', "i've", 'wasn', "mustn't", 'no', 'this', 'once', 'too', 'in', 'until', 'but', 'don', 'can', 'had', 'am', 'all', "aren't", 'doesn', "we're", 'yourself', 'few', "hasn't", "he'd", "he'll", 'such', 'an', 'above', "didn't", 're', 'haven', 'them', "don't", 'me', "i'd", "they'll", 'against', 'both', 'of', 'same', "she'll", 'through', 'if', 'do', 'as', 'couldn', 'hers', "might
# ...

# %%
filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("After Stop Word Removal:", filtered_words)
# Out:
# After Stop Word Removal: ['Natural', 'Language', 'Processing', 'important', 'area', 'Artificial', 'Intelligence']

# %%
print("Tokens:", tokens)
print("After Stop Word Removal:", filtered_words)
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'is', 'a', 'very', 'important', 'area', 'in', 'Artificial', 'Intelligence']
# After Stop Word Removal: ['Natural', 'Language', 'Processing', 'important', 'area', 'Artificial', 'Intelligence']
